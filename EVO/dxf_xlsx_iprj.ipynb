# %%
from evo_py.dxf_iprj_excel_conv import *

# %%
dxf='.dxf'
xl='sh-55 & banks_23.xlsx'

dxf_to_excel(dxf, xl, 2000)
# Out:
# Reading DXF file: banks detection.dxf
# Found 1 entities in Background layer
#   Found 3DFACE with 4 points
# Using 3DFACE as background rectangle
# Using origin at: (2527698.787607, 882013.927483) survey feet
# Meter per pixel: 0.0762, Scale factor: 4.0
# Processing 13 entities in Sensor1 layer
# Found sensor circle at (2527958.779871, 881375.482422)
# Converted to pixel coordinates (1039.9690559990704, 2553.7802439997904)
# Found 12 potential event zone polygons
# Processing event zone 1 of type 3DFACE
# Event zone has 4 points
# Processing event zone 2 of type 3DFACE
# Event zone has 4 points
# Processing event zone 3 of type 3DFACE
# Event zone has 4 points
# Processing event zone 4 of type 3DFACE
# Event zone has 4 points
# Processing event zone 5 of type 3DFACE
# Event zone has 4 points
# Processing event zone 6 of type 3DFACE
# Event zone has 4 points
# Processing event zone 7 of type 3DFACE
# Event zone has 4 points
# Processing event zone 8 of type 3DFACE
# ...

# %%
iprj='1&2_noBIU4.iprj'
xl='banks_evo_1&2_noBIU4.xlsx'

iprj_to_excel(iprj, xl)
# Out:
# c:\Users\rhansen\Documents\Python\EVO\evo_py\dxf_iprj_excel_conv.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: str(x) if isinstance(x, (dict, list)) else ("" if x is None else x))
# c:\Users\rhansen\Documents\Python\EVO\evo_py\dxf_iprj_excel_conv.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: str(x) if isinstance(x, (dict, list)) else ("" if x is None else x))
# c:\Users\rhansen\Documents\Python\EVO\evo_py\dxf_iprj_excel_conv.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: str(x) if isinstance(x, (dict, list)) else ("" if x is None else x))
# c:\Users\rhansen\Documents\Python\EVO\evo_py\dxf_iprj_excel_conv.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
xl='ex27bg.xlsx'
iprj='ex27.iprj'

xl='ex27_1&2.xlsx'
iprj='ex27_1&2_20251028.iprj'

excel_to_iprj(xl,iprj)
# Out:
# Successfully converted ex27_1&2.xlsx to ex27_1&2_20251028.iprj
